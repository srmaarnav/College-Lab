# %% [markdown]
# ##Write a program to find the various statistical measures (mean median, model, etc) based on the sample dataset

# %%
# dataset_url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'

# %%
# import pandas as pd
# import numpy as np

# %%
# # Define the column names
# columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

# # Load the dataset into a DataFrame
# pima = pd.read_csv(dataset_url, names=columns)

# %%
# # To display the first few rows of the dataset to understand its structure
# print("First few rows of the dataset:")
# print(pima.head(), "\n")
# Out:
# First few rows of the dataset:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# # Calculate the mean of each column
# mean_values = pima.mean()
# print("Mean of each column:")
# print(mean_values, "\n")
# Out:
# Mean of each column:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
# # Calculate the median of each column
# median_values = pima.median()
# print("Median of each column:")
# print(median_values, "\n")
# Out:
# Median of each column:
# Pregnancies                   3.0000
# Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                23.0000
# Insulin                      30.5000
# BMI                          32.0000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# Outcome                       0.0000
# dtype: float64

# %%
# # Calculate the mode of each column
# # Mode can have multiple values, so it's a DataFrame itself
# mode_values = pima.mode().iloc[0]  # Taking the first mode value if there are multiple modes
# print("Mode of each column:")
# print(mode_values, "\n")
# Out:
# Mode of each column:
# Pregnancies                  1.000
# Glucose                     99.000
# BloodPressure               70.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                         32.000
# DiabetesPedigreeFunction     0.254
# Age                         22.000
# Outcome                      0.000
# Name: 0, dtype: float64

# %%
# # Calculate the standard deviation of each column
# std_dev_values = pima.std()
# print("Standard Deviation of each column:")
# print(std_dev_values, "\n")
# Out:
# Standard Deviation of each column:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
# # Calculate the variance of each column
# variance_values = pima.var()
# print("Variance of each column:")
# print(variance_values, "\n")
# Out:
# Variance of each column:
# Pregnancies                    11.354056
# Glucose                      1022.248314
# BloodPressure                 374.647271
# SkinThickness                 254.473245
# Insulin                     13281.180078
# BMI                            62.159984
# DiabetesPedigreeFunction        0.109779
# Age                           138.303046
# Outcome                         0.227483
# dtype: float64

# %%
# # Calculate the minimum and maximum values of each column
# min_values = pima.min()
# max_values = pima.max()
# print("Minimum values of each column:")
# print(min_values, "\n")
# print("Maximum values of each column:")
# print(max_values, "\n")
# Out:
# Minimum values of each column:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64
#
# Maximum values of each column:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
# # Calculate the summary statistics using describe() method
# # This includes count, mean, std, min, 25%, 50%, 75%, and max
# summary_statistics = pima.describe()
# print("Summary statistics of the dataset:")
# print(summary_statistics)
# Out:
# Summary statistics of the dataset:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
import pandas as pd
import numpy as np

dataset_url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'

# Define the column names
columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

# Load the dataset into a DataFrame
pima = pd.read_csv(dataset_url, names=columns)

# To display the first few rows of the dataset to understand its structure
print("First few rows of the dataset:")
print(pima.head(), "\n")

# Calculate the mean of each column
mean_values = pima.mean()
print("Mean of each column:")
print(mean_values, "\n")

# Calculate the median of each column
median_values = pima.median()
print("Median of each column:")
print(median_values, "\n")

# Calculate the mode of each column
# Mode can have multiple values, so it's a DataFrame itself
mode_values = pima.mode().iloc[0]  # Taking the first mode value if there are multiple modes
print("Mode of each column:")
print(mode_values, "\n")

summary_statistics = pima.describe()
print("Summary statistics of the dataset:")
print(summary_statistics)
# Out:
# First few rows of the dataset:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
#
# Mean of each column:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# ...

# %% [markdown]
# ## Write a program to illustrate the data visualization based on your own sample dataset.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

dataset_url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'

# Define the column names
columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

# Load the dataset into a DataFrame
pima = pd.read_csv(dataset_url, names=columns)

# Histogram for each column
plt.figure(figsize=(12, 8))
pima.hist(bins=15, figsize=(15, 10), layout=(3, 3))
plt.suptitle('Histogram of Each Feature')
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# Boxplot for each column
plt.figure(figsize=(12, 8))
sns.boxplot(data=pima, orient='h', palette='Set2')
plt.title('Boxplot of Each Feature')
plt.show()

# Heatmap for correlation between the features
plt.figure(figsize=(10, 8))
correlation_matrix = pima.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
# # Histogram for each column
# plt.figure(figsize=(12, 8))
# pima.hist(bins=15, figsize=(15, 10), layout=(3, 3))
# plt.suptitle('Histogram of Each Feature')
# plt.tight_layout(rect=[0, 0, 1, 0.96])
# plt.show()

# %%
# # Boxplot for each column
# plt.figure(figsize=(12, 8))
# sns.boxplot(data=pima, orient='h', palette='Set2')
# plt.title('Boxplot of Each Feature')
# plt.show()

# %%
# # Heatmap for correlation between the features
# plt.figure(figsize=(10, 8))
# correlation_matrix = pima.corr()
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
# plt.title('Heatmap of Correlation Matrix')
# plt.show()

# %% [markdown]
# ##Write a program to perform some data preprocessing (discretization, sampling, remove duplicate, outlier, handle missing, noise handle, etc) in your own sample data set

# %%
# Data Preprocessing for Pima Indians Diabetes Dataset
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler

# Load the dataset
dataset_url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'
columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI',
           'DiabetesPedigreeFunction', 'Age', 'Outcome']
pima = pd.read_csv(dataset_url, names=columns)

print("Data before preprocessing:\n", pima.head())

# Handle missing values
# Replace zeros in 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', and 'BMI' with the column mean
columns_to_impute = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
imputer = SimpleImputer(missing_values=0, strategy='mean')
pima[columns_to_impute] = imputer.fit_transform(pima[columns_to_impute])

# Remove duplicate rows
pima = pima.drop_duplicates()

# Normalize the data
scaler = MinMaxScaler()
pima.iloc[:, :] = scaler.fit_transform(pima)

print("\nData after preprocessing:\n", pima.head())
# Out:
# Data before preprocessing:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
#
# Data after preprocessing:
#     Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.670968       0.489796       0.304348  0.170130  0.314928
# 1     0.058824  0.264516       0.428571       0.239130  0.170130  0.171779
# ...
